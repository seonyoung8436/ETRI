# %%
cd /home/seonyoung/All
# Out:
# /home/seonyoung/All

# %%
import sklearn.linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
import pandas as pds
core_input=[1,2,3]
core_output=[5]
train_data='only_freq.csv'

train_dataX=pds.read_csv(train_data, usecols=core_input)
train_dataY=pds.read_csv(train_data, usecols=core_output)

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import mean_absolute_error

import numpy as np
np.random.seed(4)

model=Sequential()

model.add(Dense(12,input_dim=train_dataX.shape[1],activation = 'relu'))
#train_dataX.shape[1]
#model.add(Dense(2,activation = 'relu'))
#model.add(Dense(6,activation = 'relu'))
model.add(Dense(1,activation = 'linear'))

model.compile(loss='mean_absolute_error', optimizer='adam')

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import StratifiedKFold
import numpy as np

seed = 4
np.random.seed(seed)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []

for train, test in kfold.split(train_dataX, train_dataY):
  # create model
    model = Sequential()
    model.add(Dense(12,input_dim=train_dataX.shape[1],activation = 'relu'))
    #model.add(Dense(2,activation = 'relu'))
    #model.add(Dense(6,activation = 'relu'))
    model.add(Dense(1,activation = 'linear'))
    
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Fit the model
    model.fit(train_dataX, train_dataY, epochs=150, batch_size=10, verbose=0)
    # evaluate the model
    scores = model.evaluate(train_dataX, Y, verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
    print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))

# %%
model.fit(train_dataX, train_dataY, batch_size=2048,epochs=300, verbose=1)
# Out:
# Train on 1742801 samples, validate on 193645 samples
# Epoch 1/300
# 1742801/1742801 [==============================] - 1s 1us/step - loss: 0.9863 - val_loss: 0.8398
# Epoch 2/300
# 1742801/1742801 [==============================] - 1s 1us/step - loss: 0.9857 - val_loss: 0.8400
# Epoch 3/300
# 1742801/1742801 [==============================] - 1s 1us/step - loss: 0.9859 - val_loss: 0.8371
# Epoch 4/300
# 1742801/1742801 [==============================] - 1s 1us/step - loss: 0.9856 - val_loss: 0.8455
# Epoch 5/300
# 1742801/1742801 [==============================] - 1s 1us/step - loss: 0.9860 - val_loss: 0.8427
# Epoch 6/300
# 1742801/1742801 [==============================] - 1s 1us/step - loss: 0.9861 - val_loss: 0.8450
# Epoch 7/300
# 1742801/1742801 [==============================] - 1s 1us/step - loss: 0.9859 - val_loss: 0.8452
# Epoch 8/300
# 1742801/1742801 [==============================] - 1s 1us/step - loss: 0.9856 - val_loss: 0.8381
# Epoch 9/300
# ...

# %%
from sklearn.model_selection import StratifiedKFold
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=4)
cvscores = []
for train, test in kfold.split(train_dataX, train_dataY):
  # create model
    model = Sequential()
    model.add(Dense(12,input_dim=train_dataX.shape[1],activation = 'relu'))
    #model.add(Dense(2,activation = 'relu'))
    #model.add(Dense(6,activation = 'relu'))
    model.add(Dense(1,activation = 'linear'))
    
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Fit the model
    model.fit(train_dataX[train], train_dataY[train], epochs=150, batch_size=10, verbose=0)
    # evaluate the model
    scores = model.evaluate(train_dataX[test], Y[test], verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
    print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4c8b7e1a64a7> in <module>()
#      13     model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#      14     # Fit the model
# ---> 15     model.fit(train_dataX[train], train_dataY[train], epochs=150, batch_size=10, verbose=0)
#      16     # evaluate the model
#      17     scores = model.evaluate(train_dataX[test], Y[test], verbose=0)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ...

# %%
cd /home/seonyoung/Desktop/s/only_freq/8core/
# Out:
# /home/seonyoung/Desktop/s/only_freq/8core

# %%
test_data='wrf.csv'
test_dataX=pds.read_csv(test_data, usecols=core_input)
test_dataY=pds.read_csv(test_data, usecols=core_output)

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
    
dataY_predict=model.predict(test_dataX)

resultData=DataFrame(dataY_predict)
    

resultData['answer']=test_dataY

resultData.plot(figsize=(30,10), grid=1, title="Temperature Prediction")
plt.show()

# %%
import sklearn.metrics as sm
print(sm.mean_absolute_error(dataY_predict,test_dataY))
print(sm.mean_squared_error(dataY_predict,test_dataY))
# Out:
# 0.9248143474173064
# 2.6474504360454016
